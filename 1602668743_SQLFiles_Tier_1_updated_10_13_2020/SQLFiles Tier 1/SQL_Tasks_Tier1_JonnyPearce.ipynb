# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM FACILITIES
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)

# %%
#Q10: Produce a list of facilities with a total revenue less than 1000.
#The output of facility name and total revenue, sorted by revenue. Remember
#that there's a different cost for guests and members! 

#I can get to this point where I can return the the facilities with their individual valuses, but can't sum them up

import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def facilities_rev_less_than_1000(conn):
    """
    Query facilities with revenue less than $1000
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT f.name, 
        CASE
        WHEN b.memid = 0 THEN (SELECT b.slots*f.guestcost)
        WHEN b.memid <> 0 THEN (SELECT b.slots*f.membercost)
        END AS booking_cost
        FROM FACILITIES AS f
        LEFT JOIN BOOKINGS AS b
        ON f.facid = b.facid
        WHERE booking_cost <> 0
        ORDER BY f.name
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("10. Facilities with revenue less than 1000")
        facilities_rev_less_than_1000(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 10. Facilities with revenue less than 1000
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ('Badminton Court', 46.5)
# ...

# %%
#QUESTION 11

import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def recommended_members(conn):
    """
    Query who recommended members, but not guests
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT M.surname || ' ' || M.firstname, R.surname || ' ' || R.firstname
        FROM MEMBERS as M
        LEFT JOIN MEMBERS as R
        ON R.recommendedby = M.memid  
        WHERE M.recommendedby <> 0
        ORDER BY M.surname || ' ' || M.firstname    
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)

        

def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("11. Who recommended members")
        recommended_members(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 11. Who recommended members
# ('Bader Florence', 'Sarwin Ramnaresh')
# ('Baker Anne', None)
# ('Baker Timothy', 'Coplin Joan')
# ('Boothe Tim', None)
# ('Butters Gerald', 'Genting Matthew')
# ('Coplin Joan', None)
# ('Crumpet Erica', None)
# ('Dare Nancy', None)
# ('Farrell David', None)
# ('Farrell Jemima', 'Baker Timothy')
# ('Farrell Jemima', 'Pinker David')
# ('GUEST GUEST', None)
# ('Genting Matthew', 'Rumney Henrietta')
# ('Hunt John', None)
# ('Jones David', 'Jones Douglas')
# ('Jones Douglas', None)
# ('Joplette Janice', 'Dare Nancy')
# ('Joplette Janice', 'Jones David')
# ('Mackenzie Anna', None)
# ('Owen Charles', None)
# ('Pinker David', None)
# ('Purview Millicent', 'Hunt John')
# ('Rownam Tim', 'Boothe Tim')
# ('Rumney Henrietta', None)
# ('Sarwin Ramnaresh', None)
# ('Smith Darren', 'Joplette Janice')
# ('Smith Darren', 'Butters Gerald')
# ('Smith Darren', 'Owen Charles')
# ('Smith Darren', 'Smith Jack')
# ('Smith Darren', 'Mackenzie Anna')
# ...

# %%
#QUESTION 12

import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def facility_usage(conn):
    """
    Query facility usage by members, but not guests
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT DISTINCT f.name AS facility, m.firstname || ' ' || m.surname AS memb_name,  b.slots AS no_slots
        FROM MEMBERS AS m
        LEFT JOIN BOOKINGS AS b
        ON m.memid = b.memid
        INNER JOIN FACILITIES AS f
        ON b.facid = f.facid
        WHERE b.memid >0
        ORDER BY b.facid
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)

        

def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("12. Facility usage by members")
        facility_usage(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 12. Facility usage by members
# ('Tennis Court 1', 'Tracy Smith', 3)
# ('Tennis Court 1', 'Tim Rownam', 3)
# ('Tennis Court 1', 'Janice Joplette', 3)
# ('Tennis Court 1', 'Gerald Butters', 3)
# ('Tennis Court 1', 'Burton Tracy', 3)
# ('Tennis Court 1', 'Nancy Dare', 9)
# ('Tennis Court 1', 'Nancy Dare', 3)
# ('Tennis Court 1', 'Tim Boothe', 3)
# ('Tennis Court 1', 'Charles Owen', 3)
# ('Tennis Court 1', 'Anne Baker', 3)
# ('Tennis Court 1', 'Jack Smith', 3)
# ('Tennis Court 1', 'David Jones', 3)
# ('Tennis Court 1', 'Timothy Baker', 3)
# ('Tennis Court 1', 'Jack Smith', 6)
# ('Tennis Court 1', 'Timothy Baker', 6)
# ('Tennis Court 1', 'David Pinker', 3)
# ('Tennis Court 1', 'Ponder Stibbons', 3)
# ('Tennis Court 1', 'David Jones', 6)
# ('Tennis Court 1', 'Joan Coplin', 3)
# ('Tennis Court 1', 'Douglas Jones', 3)
# ('Tennis Court 1', 'Ramnaresh Sarwin', 3)
# ('Tennis Court 1', 'Jemima Farrell', 3)
# ('Tennis Court 1', 'David Farrell', 3)
# ('Tennis Court 1', 'David Pinker', 6)
# ...

# %%
#QUESTION 13

#Don't understand why this doesn't return all the months

import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def monthly_facility_usage(conn):
    """
    Query monthly facility usage for members, not guests
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT f.name as facility, STRFTIME("%m-%Y", b.starttime) AS month, SUM(b.slots) AS no_slots
        FROM FACILITIES as f
        LEFT JOIN BOOKINGS AS b
        ON f.facid = b.facid
        WHERE B.memid >0
        GROUP BY b.facid;
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)

        

def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("13. Monthly facility usage")
        monthly_facility_usage(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 13. Monthly facility usage
# ('Tennis Court 1', '07-2012', 957)
# ('Tennis Court 2', '07-2012', 882)
# ('Badminton Court', '07-2012', 1086)
# ('Table Tennis', '07-2012', 794)
# ('Massage Room 1', '07-2012', 884)
# ('Massage Room 2', '07-2012', 54)
# ('Squash Court', '07-2012', 418)
# ('Snooker Table', '07-2012', 860)
# ('Pool Table', '07-2012', 856)
